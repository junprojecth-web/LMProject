# %%
import pandas as pd
import os

# ============================================================
# 1. 기본 설정
# ============================================================

INPUT_FILE = "processed_ml_dataset.csv"
OUTPUT_FILE = "crop_master_100.csv"


# ============================================================
# 2. 100종 작물 표준 정보
#
# crop_name_ko      : 현재 데이터셋의 한글명
# crop_name_en      : 표준 영어명
# scientific_name   : 학명
# category          : 과수 / 작물
# dataset_alias     : 이미지 데이터셋 검색용 이름
# ============================================================

crop_info = {

    "애플망고": {
        "en": "Apple Mango",
        "scientific": "Mangifera indica",
        "category": "과수",
        "alias": "apple mango|mango|mangifera|mango leaf|mango leaves"
    },

    "파파야": {
        "en": "Papaya",
        "scientific": "Carica papaya",
        "category": "과수",
        "alias": "papaya|papaya leaf|papaya leaves"
    },

    "용과": {
        "en": "Dragon Fruit",
        "scientific": "Selenicereus undatus",
        "category": "과수",
        "alias": "dragon fruit|dragonfruit|pitaya|pitahaya|hylocereus"
    },

    "패션후르츠(백향과)": {
        "en": "Passion Fruit",
        "scientific": "Passiflora edulis",
        "category": "과수",
        "alias": "passion fruit|passionfruit|passiflora edulis|passion flower"
    },

    "아보카도": {
        "en": "Avocado",
        "scientific": "Persea americana",
        "category": "과수",
        "alias": "avocado|avocado leaf|persea americana"
    },

    "구아바": {
        "en": "Guava",
        "scientific": "Psidium guajava",
        "category": "과수",
        "alias": "guava|guava leaf|psidium guajava"
    },

    "리치": {
        "en": "Lychee",
        "scientific": "Litchi chinensis",
        "category": "과수",
        "alias": "lychee|litchi|litchi chinensis|lychee leaf"
    },

    "람부탄": {
        "en": "Rambutan",
        "scientific": "Nephelium lappaceum",
        "category": "과수",
        "alias": "rambutan|nephelium lappaceum|rambutan leaf"
    },

    "망고스틴": {
        "en": "Mangosteen",
        "scientific": "Garcinia mangostana",
        "category": "과수",
        "alias": "mangosteen|garcinia mangostana|mangosteen leaf"
    },

    "두리안": {
        "en": "Durian",
        "scientific": "Durio zibethinus",
        "category": "과수",
        "alias": "durian|durio zibethinus|durian leaf"
    },

    "스타후르츠": {
        "en": "Star Fruit",
        "scientific": "Averrhoa carambola",
        "category": "과수",
        "alias": "star fruit|starfruit|carambola|averrhoa carambola"
    },

    "잭후르츠": {
        "en": "Jackfruit",
        "scientific": "Artocarpus heterophyllus",
        "category": "과수",
        "alias": "jackfruit|jack fruit|artocarpus heterophyllus"
    },

    "사포딜라": {
        "en": "Sapodilla",
        "scientific": "Manilkara zapota",
        "category": "과수",
        "alias": "sapodilla|manilkara zapota|sapota"
    },

    "롱간(용안)": {
        "en": "Longan",
        "scientific": "Dimocarpus longan",
        "category": "과수",
        "alias": "longan|longan fruit|dimocarpus longan"
    },

    "체리모야": {
        "en": "Cherimoya",
        "scientific": "Annona cherimola",
        "category": "과수",
        "alias": "cherimoya|annona cherimola|custard apple"
    },

    "아세로라": {
        "en": "Acerola",
        "scientific": "Malpighia emarginata",
        "category": "과수",
        "alias": "acerola|acerola cherry|malpighia emarginata"
    },

    "아키": {
        "en": "Ackee",
        "scientific": "Blighia sapida",
        "category": "과수",
        "alias": "ackee|akee|blighia sapida"
    },

    "페이조아": {
        "en": "Feijoa",
        "scientific": "Acca sellowiana",
        "category": "과수",
        "alias": "feijoa|acca sellowiana|pineapple guava"
    },

    "자부티카바": {
        "en": "Jabuticaba",
        "scientific": "Plinia cauliflora",
        "category": "과수",
        "alias": "jabuticaba|jaboticaba|plinia cauliflora"
    },

    "피타야(노란용과)": {
        "en": "Yellow Dragon Fruit",
        "scientific": "Selenicereus megalanthus",
        "category": "과수",
        "alias": "yellow dragon fruit|yellow pitaya|yellow pitahaya|selenicereus megalanthus"
    },

    "노니": {
        "en": "Noni",
        "scientific": "Morinda citrifolia",
        "category": "과수",
        "alias": "noni|morinda citrifolia|noni fruit"
    },

    "블랙사포테": {
        "en": "Black Sapote",
        "scientific": "Diospyros nigra",
        "category": "과수",
        "alias": "black sapote|diospyros nigra|chocolate pudding fruit"
    },

    "화이트사포테": {
        "en": "White Sapote",
        "scientific": "Casimiroa edulis",
        "category": "과수",
        "alias": "white sapote|casimiroa edulis"
    },

    "살락": {
        "en": "Salak",
        "scientific": "Salacca zalacca",
        "category": "과수",
        "alias": "salak|snake fruit|salacca zalacca"
    },

    "마르멜로(퀸스)": {
        "en": "Quince",
        "scientific": "Cydonia oblonga",
        "category": "과수",
        "alias": "quince|cydonia oblonga|quince fruit"
    },

    "산수유가공용 무화과": {
        "en": "Fig",
        "scientific": "Ficus carica",
        "category": "과수",
        "alias": "fig|fig fruit|fig tree|ficus carica|fig leaf"
    },

    "카람볼라 바이올렛": {
        "en": "Purple Carambola",
        "scientific": "Averrhoa carambola",
        "category": "과수",
        "alias": "purple carambola|carambola|star fruit|starfruit"
    },

    "플룸코트": {
        "en": "Plumcot",
        "scientific": "Prunus hybrid",
        "category": "과수",
        "alias": "plumcot|plum-apricot hybrid|pluot"
    },

    "핑거라임": {
        "en": "Finger Lime",
        "scientific": "Citrus australasica",
        "category": "과수",
        "alias": "finger lime|citrus australasica|caviar lime"
    },

    "부다스핸드": {
        "en": "Buddha's Hand Citron",
        "scientific": "Citrus medica var. sarcodactylis",
        "category": "과수",
        "alias": "buddha hand|buddhas hand|fingered citron|citron|citrus medica"
    },

    "오크라": {
        "en": "Okra",
        "scientific": "Abelmoschus esculentus",
        "category": "작물",
        "alias": "okra|abelmoschus esculentus|lady finger"
    },

    "공심채": {
        "en": "Water Spinach",
        "scientific": "Ipomoea aquatica",
        "category": "작물",
        "alias": "water spinach|kangkong|morning glory|ipomoea aquatica"
    },

    "여주": {
        "en": "Bitter Melon",
        "scientific": "Momordica charantia",
        "category": "작물",
        "alias": "bitter melon|bitter gourd|momordica charantia"
    },

    "차요테": {
        "en": "Chayote",
        "scientific": "Sechium edule",
        "category": "작물",
        "alias": "chayote|sechium edule|vegetable pear"
    },

    "아티초크": {
        "en": "Artichoke",
        "scientific": "Cynara cardunculus var. scolymus",
        "category": "작물",
        "alias": "artichoke|globe artichoke|cynara"
    },

    "카사바": {
        "en": "Cassava",
        "scientific": "Manihot esculenta",
        "category": "작물",
        "alias": "cassava|manioc|yuca|manihot esculenta"
    },

    "얌(대마)": {
        "en": "Yam",
        "scientific": "Dioscorea spp.",
        "category": "작물",
        "alias": "yam|dioscorea|yam root"
    },

    "타로": {
        "en": "Taro",
        "scientific": "Colocasia esculenta",
        "category": "작물",
        "alias": "taro|colocasia esculenta|taro root"
    },

    "자색마": {
        "en": "Purple Yam",
        "scientific": "Dioscorea alata",
        "category": "작물",
        "alias": "purple yam|ube|dioscorea alata"
    },

    "아라카차": {
        "en": "Arracacha",
        "scientific": "Arracacia xanthorrhiza",
        "category": "작물",
        "alias": "arracacha|arracacia xanthorrhiza"
    },

    "제이콘(야콘)": {
        "en": "Yacon",
        "scientific": "Smallanthus sonchifolius",
        "category": "작물",
        "alias": "yacon|smallanthus sonchifolius|yacon root"
    },

    "줄기상추(궁채)": {
        "en": "Stem Lettuce",
        "scientific": "Lactuca sativa var. angustana",
        "category": "작물",
        "alias": "stem lettuce|asparagus lettuce|celtuce|lactuca sativa"
    },

    "골든비트": {
        "en": "Golden Beet",
        "scientific": "Beta vulgaris",
        "category": "작물",
        "alias": "golden beet|golden beetroot|beet|beta vulgaris"
    },

    "로마네스코": {
        "en": "Romanesco Broccoli",
        "scientific": "Brassica oleracea",
        "category": "작물",
        "alias": "romanesco|romanesco broccoli|romanesco cauliflower|brassica oleracea"
    },

    "아스파라거스 콩": {
        "en": "Yardlong Bean",
        "scientific": "Vigna unguiculata subsp. sesquipedalis",
        "category": "작물",
        "alias": "yardlong bean|long bean|asparagus bean|snake bean"
    },

    "윙드빈(사각콩)": {
        "en": "Winged Bean",
        "scientific": "Psophocarpus tetragonolobus",
        "category": "작물",
        "alias": "winged bean|wing bean|psophocarpus tetragonolobus"
    },

    "워터체스트넛": {
        "en": "Water Chestnut",
        "scientific": "Eleocharis dulcis",
        "category": "작물",
        "alias": "water chestnut|chinese water chestnut|eleocharis dulcis"
    },

    "고수": {
        "en": "Cilantro",
        "scientific": "Coriandrum sativum",
        "category": "작물",
        "alias": "cilantro|coriander|coriandrum sativum"
    },

    "레몬그라스": {
        "en": "Lemongrass",
        "scientific": "Cymbopogon citratus",
        "category": "작물",
        "alias": "lemongrass|lemon grass|cymbopogon citratus"
    },

    "갈랑갈": {
        "en": "Galangal",
        "scientific": "Alpinia galanga",
        "category": "작물",
        "alias": "galangal|greater galangal|alpinia galanga"
    },

    "타이바질": {
        "en": "Thai Basil",
        "scientific": "Ocimum basilicum",
        "category": "작물",
        "alias": "thai basil|basil|ocimum basilicum"
    },

    "커리잎": {
        "en": "Curry Leaf",
        "scientific": "Murraya koenigii",
        "category": "작물",
        "alias": "curry leaf|curry leaves|murraya koenigii"
    },

    "몰로키아": {
        "en": "Molokhia",
        "scientific": "Corchorus olitorius",
        "category": "작물",
        "alias": "molokhia|jute mallow|corchorus olitorius"
    },

    "아이스플랜트": {
        "en": "Ice Plant",
        "scientific": "Mesembryanthemum crystallinum",
        "category": "작물",
        "alias": "ice plant|crystalline iceplant|mesembryanthemum crystallinum"
    },

    "핑거루트": {
        "en": "Fingerroot",
        "scientific": "Boesenbergia rotunda",
        "category": "작물",
        "alias": "fingerroot|boesenbergia rotunda|chinese ginger"
    },

    "강황": {
        "en": "Turmeric",
        "scientific": "Curcuma longa",
        "category": "작물",
        "alias": "turmeric|curcuma longa|turmeric leaf"
    },

    "차조기(자소엽)": {
        "en": "Perilla",
        "scientific": "Perilla frutescens",
        "category": "작물",
        "alias": "perilla|shiso|perilla frutescens|perilla leaf"
    },

    "파카야": {
        "en": "Pakaya",
        "scientific": "Unknown / local cultivar",
        "category": "작물",
        "alias": "pakaya"
    },

    "스네이크고드": {
        "en": "Snake Gourd",
        "scientific": "Trichosanthes cucumerina",
        "category": "작물",
        "alias": "snake gourd|snakegourd|trichosanthes cucumerina"
    },

    "비터토마토": {
        "en": "Bitter Tomato",
        "scientific": "Solanum aethiopicum",
        "category": "작물",
        "alias": "bitter tomato|garden egg|solanum aethiopicum"
    },

    "퀴노아": {
        "en": "Quinoa",
        "scientific": "Chenopodium quinoa",
        "category": "작물",
        "alias": "quinoa|chenopodium quinoa"
    },

    "아마란스": {
        "en": "Amaranth",
        "scientific": "Amaranthus spp.",
        "category": "작물",
        "alias": "amaranth|amaranthus|amaranth leaf"
    },

    "테프": {
        "en": "Teff",
        "scientific": "Eragrostis tef",
        "category": "작물",
        "alias": "teff|tef|eragrostis tef"
    },

    "카카오": {
        "en": "Cacao",
        "scientific": "Theobroma cacao",
        "category": "작물",
        "alias": "cacao|cocoa|theobroma cacao|cacao leaf"
    },

    "커피나무": {
        "en": "Coffee",
        "scientific": "Coffea arabica",
        "category": "작물",
        "alias": "coffee|coffee plant|coffee leaf|coffea arabica"
    },

    "바닐라": {
        "en": "Vanilla",
        "scientific": "Vanilla planifolia",
        "category": "작물",
        "alias": "vanilla|vanilla plant|vanilla orchid|vanilla planifolia"
    },

    "블랙페퍼(후추)": {
        "en": "Black Pepper",
        "scientific": "Piper nigrum",
        "category": "작물",
        "alias": "black pepper|peppercorn|piper nigrum|pepper plant"
    },

    "육두구": {
        "en": "Nutmeg",
        "scientific": "Myristica fragrans",
        "category": "작물",
        "alias": "nutmeg|myristica fragrans"
    },

    "정향": {
        "en": "Clove",
        "scientific": "Syzygium aromaticum",
        "category": "작물",
        "alias": "clove|clove tree|syzygium aromaticum"
    },

    "육계(계피)": {
        "en": "Cinnamon",
        "scientific": "Cinnamomum verum",
        "category": "작물",
        "alias": "cinnamon|cinnamon tree|cinnamomum verum"
    },

    "사프란": {
        "en": "Saffron",
        "scientific": "Crocus sativus",
        "category": "작물",
        "alias": "saffron|crocus sativus|saffron flower"
    },

    "카다멈": {
        "en": "Cardamom",
        "scientific": "Elettaria cardamomum",
        "category": "작물",
        "alias": "cardamom|green cardamom|elettaria cardamomum"
    },

    "올스파이스": {
        "en": "Allspice",
        "scientific": "Pimenta dioica",
        "category": "작물",
        "alias": "allspice|pimenta dioica"
    },

    "과라나": {
        "en": "Guarana",
        "scientific": "Paullinia cupana",
        "category": "작물",
        "alias": "guarana|paullinia cupana"
    },

    "마카": {
        "en": "Maca",
        "scientific": "Lepidium meyenii",
        "category": "작물",
        "alias": "maca|maca root|lepidium meyenii"
    },

    "사차인치": {
        "en": "Sacha Inchi",
        "scientific": "Plukenetia volubilis",
        "category": "작물",
        "alias": "sacha inchi|inca peanut|plukenetia volubilis"
    },

    "브라질넛": {
        "en": "Brazil Nut",
        "scientific": "Bertholletia excelsa",
        "category": "작물",
        "alias": "brazil nut|bertholletia excelsa"
    },

    "캐슈넛": {
        "en": "Cashew",
        "scientific": "Anacardium occidentale",
        "category": "과수",
        "alias": "cashew|cashew nut|anacardium occidentale|cashew leaf"
    },

    "마카다미아": {
        "en": "Macadamia",
        "scientific": "Macadamia integrifolia",
        "category": "과수",
        "alias": "macadamia|macadamia nut|macadamia integrifolia|macadamia leaf"
    },

    "사탕수수": {
        "en": "Sugarcane",
        "scientific": "Saccharum officinarum",
        "category": "작물",
        "alias": "sugarcane|sugar cane|saccharum officinarum"
    },

    "스테비아": {
        "en": "Stevia",
        "scientific": "Stevia rebaudiana",
        "category": "작물",
        "alias": "stevia|stevia rebaudiana"
    },

    "모링가": {
        "en": "Moringa",
        "scientific": "Moringa oleifera",
        "category": "작물",
        "alias": "moringa|moringa oleifera|moringa leaf"
    },

    "아사이베리": {
        "en": "Acai Berry",
        "scientific": "Euterpe oleracea",
        "category": "과수",
        "alias": "acai|acai berry|euterpe oleracea"
    },

    "마키베리": {
        "en": "Maqui Berry",
        "scientific": "Aristotelia chilensis",
        "category": "과수",
        "alias": "maqui|maqui berry|aristotelia chilensis"
    },

    "카무카무": {
        "en": "Camu Camu",
        "scientific": "Myrciaria dubia",
        "category": "과수",
        "alias": "camu camu|camu-camu|myrciaria dubia"
    },

    "인디안구스베리(암라)": {
        "en": "Indian Gooseberry",
        "scientific": "Phyllanthus emblica",
        "category": "과수",
        "alias": "indian gooseberry|amla|amalaki|phyllanthus emblica"
    },

    "고투콜라(병풀)": {
        "en": "Gotu Kola",
        "scientific": "Centella asiatica",
        "category": "작물",
        "alias": "gotu kola|centella asiatica|centella|asiatic pennywort"
    },

    "홀리바질": {
        "en": "Holy Basil",
        "scientific": "Ocimum tenuiflorum",
        "category": "작물",
        "alias": "holy basil|tulsi|ocimum tenuiflorum"
    },

    "버터플라이피": {
        "en": "Butterfly Pea",
        "scientific": "Clitoria ternatea",
        "category": "작물",
        "alias": "butterfly pea|blue pea|clitoria ternatea"
    },

    "히비스커스(로젤)": {
        "en": "Roselle",
        "scientific": "Hibiscus sabdariffa",
        "category": "작물",
        "alias": "roselle|hibiscus|hibiscus sabdariffa|hibiscus flower"
    },

    "카바카바": {
        "en": "Kava",
        "scientific": "Piper methysticum",
        "category": "작물",
        "alias": "kava|kava kava|piper methysticum"
    },

    "크라통": {
        "en": "Kratom",
        "scientific": "Mitragyna speciosa",
        "category": "작물",
        "alias": "kratom|mitragyna speciosa"
    },

    "판단": {
        "en": "Pandan",
        "scientific": "Pandanus amaryllifolius",
        "category": "작물",
        "alias": "pandan|pandan leaf|pandanus amaryllifolius"
    },

    "피멘토": {
        "en": "Pimento",
        "scientific": "Capsicum annuum",
        "category": "작물",
        "alias": "pimento|pimiento|capsicum|capsicum annuum"
    },

    "하바네로": {
        "en": "Habanero Pepper",
        "scientific": "Capsicum chinense",
        "category": "작물",
        "alias": "habanero|habanero pepper|capsicum chinense"
    },

    "캐롤라이나 리퍼": {
        "en": "Carolina Reaper",
        "scientific": "Capsicum chinense",
        "category": "작물",
        "alias": "carolina reaper|carolina reaper pepper|capsicum chinense"
    },

    "차요테 덩굴 싹": {
        "en": "Chayote Shoots",
        "scientific": "Sechium edule",
        "category": "작물",
        "alias": "chayote shoots|chayote vine|chayote|sechium edule"
    },

    "스피룰리나": {
        "en": "Spirulina",
        "scientific": "Arthrospira platensis",
        "category": "작물",
        "alias": "spirulina|arthrospira|arthrospira platensis"
    },

    "기네아생강": {
        "en": "Guinea Ginger",
        "scientific": "Unknown / verify",
        "category": "작물",
        "alias": "guinea ginger"
    },

    "타마린드": {
        "en": "Tamarind",
        "scientific": "Tamarindus indica",
        "category": "과수",
        "alias": "tamarind|tamarind fruit|tamarindus indica|tamarind leaf"
    }
}


# ============================================================
# 3. 원본 데이터 불러오기
# ============================================================

if not os.path.exists(INPUT_FILE):
    print(f"❌ 파일을 찾을 수 없습니다: {INPUT_FILE}")
    print("현재 Python 파일과 processed_ml_dataset.csv가 같은 폴더인지 확인하세요.")
    exit()

df = pd.read_csv(INPUT_FILE, encoding="utf-8-sig")

print(f"원본 데이터: {len(df):,}행")


# ============================================================
# 4. 작물명 컬럼 확인
# ============================================================

if "작물명" in df.columns:
    crop_column = "작물명"
elif "crop_name" in df.columns:
    crop_column = "crop_name"
else:
    print("❌ '작물명' 또는 'crop_name' 컬럼을 찾을 수 없습니다.")
    print("현재 컬럼:")
    print(df.columns.tolist())
    exit()


# ============================================================
# 5. 원본에서 중복 제거
# ============================================================

crop_list = (
    df[crop_column]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
    .tolist()
)

print(f"원본 데이터에서 발견된 작물 수: {len(crop_list)}종")


# ============================================================
# 6. 100종 마스터 생성
# ============================================================

result = []

for crop_name in crop_list:

    if crop_name in crop_info:

        info = crop_info[crop_name]

        result.append({
            "ID": len(result) + 1,
            "crop_name_ko": crop_name,
            "crop_name_en": info["en"],
            "scientific_name": info["scientific"],
            "category": info["category"],
            "dataset_alias": info["alias"]
        })

    else:

        print(f"⚠️ 매칭되지 않은 작물: {crop_name}")


# ============================================================
# 7. CSV 저장
# ============================================================

master_df = pd.DataFrame(result)

master_df.to_csv(
    OUTPUT_FILE,
    index=False,
    encoding="utf-8-sig"
)


# ============================================================
# 8. 결과 확인
# ============================================================

print()
print("=" * 60)
print("100종 작물 마스터 데이터 생성 완료")
print("=" * 60)

print(f"생성 파일 : {OUTPUT_FILE}")
print(f"매칭 작물 : {len(master_df)}종")

print()
print("분류별 개수")
print(master_df["category"].value_counts())

print()
print("샘플")
print(master_df.head(10).to_string(index=False))
# Out:
# ...
# 100종 작물 이미지 데이터셋 자동 구축
# ...
#
# CSV에서 확인된 작물 종류: 100종
#
# 작물 목록:
#   1. 애플망고
#   2. 파파야
#   3. 용과
#   4. 패션후르츠(백향과)
#   5. 아보카도
#   6. 구아바
#   7. 리치
#   8. 람부탄
#   9. 망고스틴
#  10. 두리안
#  11. 스타후르츠
#  12. 잭후르츠
#  13. 사포딜라
#  14. 롱간(용안)
#  15. 체리모야
#  16. 아세로라
#  17. 아키
#  18. 페이조아
#  19. 자부티카바
#  20. 피타야(노란용과)
#  21. 노니
#  22. 블랙사포테
#  23. 화이트사포테
#  24. 살락
#  25. 마르멜로(퀸스)
#  26. 산수유가공용 무화과
#  27. 카람볼라 바이올렛
#  28. 플룸코트
#  29. 핑거라임
#  30. 부다스핸드
#  31. 오크라
#  32. 공심채
#  33. 여주
#  34. 차요테
#  35. 아티초크
#  36. 카사바
#  37. 얌(대마)
#  38. 타로
#  39. 자색마
#  40. 아라카차
#  41. 제이콘(야콘)
#  42. 줄기상추(궁채)
#  43. 골든비트
#  44. 로마네스코
#  45. 아스파라거스 콩
#  46. 윙드빈(사각콩)
#  47. 워터체스트넛
#  48. 고수
#  49. 레몬그라스
#  50. 갈랑갈
#  51. 타이바질
#  52. 커리잎
#  53. 몰로키아
#  54. 아이스플랜트
#  55. 핑거루트
#  56. 강황
#  57. 차조기(자소엽)
#  58. 파카야
#  59. 스네이크고드
#  60. 비터토마토
#  61. 퀴노아
#  62. 아마란스
#  63. 테프
#  64. 카카오
#  65. 커피나무
#  66. 바닐라
#  67. 블랙페퍼(후추)
#  68. 육두구
#  69. 정향
#  70. 육계(계피)
#  71. 사프란
#  72. 카다멈
#  73. 올스파이스
#  74. 과라나
#  75. 마카
# ...
